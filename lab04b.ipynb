# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://happenings.washu.edu/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

events = []
